# %%
import nb_utils
# Out:
# Moving cwd to /store/CIA/js2164/repos/diffusion/src

# %%
from matplotlib import pyplot as plt

# %%
import pickle
path = '/store/CIA/js2164/rds/gb511/projects/dimension_detection/experiments/style_gan/2_BeatGANsUNetModel/svd/svd_4999.pkl'
with open(path, 'rb') as f:
    svd = pickle.load(f)

# %%
spec = svd['singular_values'][0][-500:]
# plot spec ticks every unit
plt.plot(spec)
#plt.xticks(range(0, len(spec), 1))
plt.show()

# %%
spec = svd['singular_values'][1][-500:]
# plot spec ticks every unit
plt.plot(spec)
#plt.xticks(range(0, len(spec), 1))
plt.show()

# %%
from plot_utils import plot_distribution
plot_distribution(svd, mode='all', tail=50)
# Out:
# Aggregation mode: all
# [3, 4]
