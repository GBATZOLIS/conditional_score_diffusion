# %%
#%%
# Import required modules
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch.distributions.multivariate_normal import MultivariateNormal
from torch.distributions.mixture_same_family import MixtureSameFamily
from torch.distributions.normal import Normal
from torch.distributions.categorical import Categorical
from torch.distributions.independent import Independent
from lightning_data_modules.SyntheticDataset import SyntheticDataModule
from lightning_modules.BaseSdeGenerativeModel import BaseSdeGenerativeModel
from lightning_modules.FokkerPlanckModel import FokkerPlanckModel
from lightning_modules.ConservativeSdeGenerativeModel import ConservativeSdeGenerativeModel
from models.fcn_potential import FCN_Potential
from models.fcn import FCN
from models.utils import get_score_fn
from utils import compute_divergence, compute_grad, compute_curl, generate_grid, extract_vector_field, fisher_divergence
from plot_utils import plot_log_energy
import sde_lib

# %%
def calculate_wasserstein(batch1, batch2):
    import ot
    n_batch = batch1.shape[0]
    cost_matrix = torch.cdist(batch1, batch2) ** 2
    weights = torch.ones(n_batch)/n_batch
    wasserstein = float(ot.emd2(weights, weights, cost_matrix, numItermax=int(1e6)))
    return wasserstein

# %%
def visualise_samples(samples, title='samples', force_range=False):
    samples_np =  samples.cpu().numpy()
    plt.figure(figsize=(10,10))
    image = plt.scatter(samples_np[:,0],samples_np[:,1])
    if force_range:
        plt.ylim(-1.5,1.5)
        plt.xlim(-1.5,1.5)
    #plt.gca().set_aspect('equal')
    plt.axis('square')
    plt.savefig('figures/'+title, dpi=300)

# %%
def print_sampling_parameters(config):
    sampling = config.sampling
    model = config.model
    print('predictor:', sampling.predictor)
    print('num_time_steps', model.num_scales)
    print('corrector:', sampling.corrector)
    print('snr:',  sampling.snr)
    print('n_steps_each:', sampling.n_steps_each)
    print('probability_flow:', sampling.probability_flow)
    print('noise_removal:', sampling.noise_removal)

# %%
def get_sampling_config(config, snr=0.075, predictor='reverse_diffusion', corrector = 'none', 
                n_steps_each=1, probability_flow=False, num_scales=1000):
    
    sampling = config.sampling
    sampling.corrector = 'pc'
    sampling.predictor =  predictor
    sampling.corrector = corrector
    sampling.n_steps_each = n_steps_each
    sampling.noise_removal = True
    sampling.probability_flow = probability_flow
    sampling.snr = snr

    model = config.model
    model.num_scales = num_scales

    return config

# %%
def sample(ckpt_path, sampling_config):
    from sampling.unconditional import get_sampling_fn
    pl_module = FokkerPlanckModel.load_from_checkpoint(ckpt_path)
    score_model = pl_module.score_model
    pl_module.configure_sde(config)
    pl_module = pl_module.eval()

    num_samples = 5000   
    sde = sde_lib.VESDE(sigma_min=config.model.sigma_min, sigma_max=config.model.sigma_max, N=config.model.num_scales, data_mean=None) #pl_module.sde
    sampling_eps = 1e-5
    sampling_shape = [num_samples] +  config.data.shape
    sampling_fn = get_sampling_fn(config, sde, sampling_shape, sampling_eps)
    score_model = pl_module.score_model
    samples, _ = sampling_fn(score_model)#, show_evolution=False)
    return samples

# %% [markdown]
# # Tests

# %%
import torch.nn as nn
import pytorch_lightning as pl
class GTModel(pl.LightningModule):
    def __init__(self, gt_fn):
        super().__init__()
        self.gt_fn = gt_fn

    def forward(self, x, t):
        return self.gt_fn(x, t)

# %%
from configs.jan.gaussian.fokker_planck_gauss import get_config
from lightning_data_modules.SyntheticDataset import SyntheticDataModule
from sampling.unconditional import get_sampling_fn
config = get_config()
data_m = SyntheticDataModule(config)
data_m.setup()
dataset = data_m.dataset
num_samples = 1000  
sde = dataset.sde
sampling_eps = 1e-5
sampling_shape = [num_samples] +  config.data.shape
gamma = 1
gt_score_fn = lambda x,t: gamma * dataset.ground_truth_score(x,t)
score_model = GTModel(gt_score_fn)
sampling_fn = get_sampling_fn(config, sde, sampling_shape, sampling_eps)
samples, _ = sampling_fn(score_model)
# Out:
# 100%|██████████| 1000/1000 [00:06<00:00, 143.95it/s]

# %%
visualise_samples(samples)

# %% [markdown]
# # Gaussian Mixtures

# %% [markdown]
# ## Fokker-Planck Model

# %%
from configs.jan.gaussian.fokker_planck_gauss import get_config
config = get_config()
ckpt_path = "logs/gaussian_bubbles/fokker_planck/fp_grad-alpha_0_0001_to_0_01_deep/checkpoints/best/last.ckpt"

# %%
config = get_config()
samples = sample(ckpt_path,config)
visualise_samples(samples)
print_sampling_parameters(config)
# Out:
# 100%|██████████| 1000/1000 [00:06<00:00, 160.12it/s]
# predictor: reverse_diffusion
# num_time_steps 1000
# corrector: none
# snr: 0.075
# n_steps_each: 1
# probability_flow: False
# noise_removal: True

# %%
config_ode = get_sampling_config(config, probability_flow=True)
samples_ode = sample(ckpt_path, config_ode)
visualise_samples(samples_ode)
print_sampling_parameters(config_ode)
# Out:
# 100%|██████████| 1000/1000 [00:05<00:00, 178.15it/s]
# predictor: reverse_diffusion
# num_time_steps 1000
# corrector: none
# snr: 0.075
# n_steps_each: 1
# probability_flow: True
# noise_removal: True

# %%
calculate_wasserstein(samples, samples_ode)
# Out:
# 0.0864192321896553

# %% [markdown]
# ## Potential

# %%
from configs.jan.gaussian.fokker_planck_gauss import get_config
config = get_config()
ckpt_path = 'logs/gaussian_bubbles/fokker_planck/fp_grad-alpha_0/checkpoints/best/last.ckpt'

# %%
config = get_config()
samples = sample(ckpt_path,config)
visualise_samples(samples)
print_sampling_parameters(config)
# Out:
# 100%|██████████| 1000/1000 [00:05<00:00, 173.35it/s]
# predictor: reverse_diffusion
# num_time_steps 1000
# corrector: none
# snr: 0.075
# n_steps_each: 1
# probability_flow: False
# noise_removal: True

# %%
config_ode = get_sampling_config(config, probability_flow=True)
samples_ode = sample(ckpt_path, config_ode)
visualise_samples(samples_ode)
print_sampling_parameters(config_ode)
# Out:
# 100%|██████████| 1000/1000 [00:05<00:00, 188.73it/s]
# predictor: reverse_diffusion
# num_time_steps 1000
# corrector: none
# snr: 0.075
# n_steps_each: 1
# probability_flow: True
# noise_removal: True

# %%
calculate_wasserstein(samples, samples_ode)
# Out:
# 0.06886526197195053

# %% [markdown]
# # Circles

# %% [markdown]
# ## Potential

# %%
from configs.jan.circles.fokker_planck.fokker_planck_circles import get_config 
config = get_config()
ckpt_path = 'logs/circles/fokker_planck/proto/potential/checkpoints/best/last.ckpt'
#'logs/circles/fokker_planck/fp_grad-alpha_0_deep/checkpoints/best/last.ckpt'
#'logs/circles/fokker_planck/fp_ve_alpha_0/checkpoints/epoch=13317-step=1065439.ckpt'

# %%
config = get_config()
samples = sample(ckpt_path,config)
visualise_samples(samples, title='potential_sde')
print_sampling_parameters(config)
# Out:
# 100%|██████████| 1000/1000 [00:18<00:00, 53.14it/s]
# predictor: reverse_diffusion
# num_time_steps 1000
# corrector: none
# snr: 0.075
# n_steps_each: 1
# probability_flow: False
# noise_removal: True

# %%
config_ode = get_sampling_config(config, probability_flow=True)
samples_ode = sample(ckpt_path, config_ode)
visualise_samples(samples_ode, title='potential_ode')
print_sampling_parameters(config_ode)
# Out:
# 100%|██████████| 1000/1000 [00:21<00:00, 45.76it/s]
# predictor: reverse_diffusion
# num_time_steps 1000
# corrector: none
# snr: 0.075
# n_steps_each: 1
# probability_flow: True
# noise_removal: True

# %%
calculate_wasserstein(samples, samples_ode)
# Out:
# 0.01993657648563385

# %% [markdown]
# ## Fokker Planck

# %%
from configs.jan.circles.fokker_planck.fokker_planck_circles import get_config 
config = get_config()
ckpt_path = 'logs/circles/fokker_planck/proto/fp_1e-3/checkpoints/best/last.ckpt'
#"logs/circles/fokker_planck/fp_grad-alpha_0_01_deep_resumed/checkpoints/best/last.ckpt"
#'logs/circles/fokker_planck/fp_grad-alpha_0_0001_to_0_01_deep/checkpoints/best/last.ckpt'

# %%
config = get_config()
config.model.num_scales = num_scales
samples = sample(ckpt_path,config)
visualise_samples(samples)
print_sampling_parameters(config)
# Out:
#  12%|█▏        | 123/1000 [00:06<00:44, 19.54it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_915358/4184999218.py in <module>
#       1 config = get_config()
# ----> 2 samples = sample(ckpt_path,config)
#       3 visualise_samples(samples)
#       4 print_sampling_parameters(config)
#
# /tmp/ipykernel_915358/3378748905.py in sample(ckpt_path, sampling_config)
#      12     sampling_fn = get_sampling_fn(config, sde, sampling_shape, sampling_eps)
#      13     score_model = pl_module.score_model
# ---> 14     samples, _ = sampling_fn(score_model)#, show_evolution=False)
#      15     return samples
#
# /store/CIA/js2164/repos/diffusion_score/sampling/unconditional.py in pc_sampler(model, show_evolution)
#     182         vec_t = torch.ones(shape[0], device=t.device) * t
#     183         x, x_mean = corrector_update_fn(x, vec_t, model=model)
# --> 184         x, x_mean = predictor_update_fn(x, vec_t, model=model)
#     185
#     186         if show_evolution:
#
# /store/CIA/js2164/repos/diffusion_score/sampling/unconditional.py in shared_predictor_update_fn(x, t, sde, model, predictor, probability_flow, continuous)
#     325   else:
#     326     predictor_obj = predictor(sde, score_fn, probability_flow)
# --> 327   return predictor_obj.update_fn(x, t)
#     328
#     329 def shared_corrector_update_fn(x, t, sde, model, corrector, continuous, snr, n_steps):
#
# /store/CIA/js2164/repos/diffusion_score/sampling/predictors.py in update_fn(self, x, t)
#     137
#     138   def update_fn(self, x, t):
# --> 139     f, G = self.rsde.discretize(x, t)
#     140     z = torch.randn_like(x)
#     141     x_mean = x - f
#
# /store/CIA/js2164/repos/diffusion_score/sde_lib.py in discretize(self, x, t)
#     103         """Create discretized iteration rules for the reverse diffusion sampler."""
#     104         f, G = discretize_fn(x, t)
# --> 105         rev_f = f - G[(..., ) + (None, ) * len(x.shape[1:])] ** 2 * score_fn(x, t) * (0.5 if self.probability_flow else 1.)
#     106         rev_G = torch.zeros_like(G) if self.probability_flow else G
#     107         return rev_f, rev_G
#
# /store/CIA/js2164/repos/diffusion_score/models/utils.py in score_fn(x, t)
#     250           #std = labels = sde.marginal_prob(torch.zeros_like(x), t)[1]
#     251           #time_embedding = torch.log(labels) if model.embedding_type == 'fourier' else labels
# --> 252           score = model_fn(x, t)
#     253           #score = score / std[(...,)+(None,)*len(x.shape[1:])]
#     254         else:
#
# /store/CIA/js2164/repos/diffusion_score/models/utils.py in model_fn(x, labels)
#     145     if not train:
#     146       model.eval()
# --> 147       return model(x, labels)
#     148     else:
#     149       model.train()
#
# /store/CIA/js2164/conda_envs/score_sde/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /store/CIA/js2164/repos/diffusion_score/models/fcn_potential.py in forward(self, x, t)
#      94
#      95     def forward(self, x, t):
# ---> 96         return self.score(x,t)
#      97
#      98
#
# /store/CIA/js2164/repos/diffusion_score/models/fcn_potential.py in score(self, x, t)
#      42         with torch.enable_grad():
#      43             x = x.requires_grad_(True)
# ---> 44             out = self.log_energy(x, t)
#      45             gradients = torch.autograd.grad(outputs=out, inputs=x,
#      46                                     grad_outputs=torch.ones(out.size()).to(self.device),
#
# /store/CIA/js2164/repos/diffusion_score/models/fcn_potential.py in log_energy(self, x, t)
#      33         t = t.unsqueeze(-1)
#      34         inpt = torch.cat([x, t], dim=1)
# ---> 35         out = self.mlp(inpt)
#      36         return out
#      37
#
# /store/CIA/js2164/conda_envs/score_sde/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /store/CIA/js2164/conda_envs/score_sde/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# /store/CIA/js2164/conda_envs/score_sde/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /store/CIA/js2164/conda_envs/score_sde/lib/python3.9/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      94
#      95     def forward(self, input: Tensor) -> Tensor:
# ---> 96         return F.linear(input, self.weight, self.bias)
#      97
#      98     def extra_repr(self) -> str:
#
# /store/CIA/js2164/conda_envs/score_sde/lib/python3.9/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1845     if has_torch_function_variadic(input, weight):
#    1846         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1847     return torch._C._nn.linear(input, weight, bias)
#    1848
#    1849
#
# KeyboardInterrupt:

# %%
config_ode = get_sampling_config(config, probability_flow=True)
samples_ode = sample(ckpt_path, config_ode)
visualise_samples(samples_ode)
print_sampling_parameters(config_ode)
# Out:
# 100%|██████████| 1000/1000 [00:46<00:00, 21.42it/s]
# predictor: reverse_diffusion
# num_time_steps 1000
# corrector: none
# snr: 0.075
# n_steps_each: 1
# probability_flow: True
# noise_removal: True

# %%
calculate_wasserstein(samples, samples_ode)
# Out:
# 0.013788886368274689

# %% [markdown]
# # Vanilla

# %%
from configs.jan.circles.fokker_planck.fokker_planck_circles import get_config 
config = get_config()
ckpt_path = 'logs/circles/fokker_planck/proto/vanilla_temp/checkpoints/best/last.ckpt'
#"logs/circles/fokker_planck/fp_grad-alpha_0_01_deep_resumed/checkpoints/best/last.ckpt"
#'logs/circles/fokker_planck/fp_grad-alpha_0_0001_to_0_01_deep/checkpoints/best/last.ckpt'

# %%
config = get_config()
samples = sample(ckpt_path,config)
visualise_samples(samples)
print_sampling_parameters(config)
# Out:
# 100%|██████████| 1000/1000 [00:12<00:00, 83.31it/s]
# predictor: reverse_diffusion
# num_time_steps 1000
# corrector: none
# snr: 0.075
# n_steps_each: 1
# probability_flow: False
# noise_removal: True

# %%
config_ode = get_sampling_config(config, probability_flow=True)
samples_ode = sample(ckpt_path, config_ode)
visualise_samples(samples_ode)
print_sampling_parameters(config_ode)
# Out:
# 100%|██████████| 1000/1000 [00:11<00:00, 87.73it/s]
# predictor: reverse_diffusion
# num_time_steps 1000
# corrector: none
# snr: 0.075
# n_steps_each: 1
# probability_flow: True
# noise_removal: True

# %%
calculate_wasserstein(samples, samples_ode)
# Out:
# 0.0010741247097030282
