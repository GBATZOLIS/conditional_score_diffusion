# %%
import json
import numpy as np
from matplotlib import pyplot as plt

# %%
with open('mammoth.json', 'rb') as f:
    mammoth_list = json.load(f)

# %%
mammoth = np.array(mammoth_list)

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(10, 60)
ax.scatter(mammoth[:,0], mammoth[:,1], mammoth[:,2])
fig.show()

# %%
mammoth = mammoth - mammoth.mean() 
mammoth = mammoth / (mammoth.max() - mammoth.min())
mammoth
# Out:
# array([[-0.1421018 ,  0.23049202, -0.06738466],
#        [-0.10564875,  0.23982795, -0.07303642],
#        [-0.11668102,  0.46884032, -0.1060779 ],
#        ...,
#        [-0.07828872,  0.10658107, -0.11150159],
#        [-0.11832878,  0.32514822, -0.03780198],
#        [-0.11371479,  0.53135786, -0.19524158]])

# %%
# Out:
# 158.73957121333333

# %%
from scipy.spatial.distance import cdist
distances = cdist(mammoth, mammoth)

# %%
distances.max()
# Out:
# 0.7638721373624336
